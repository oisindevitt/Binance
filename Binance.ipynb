# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv(r'C:\\Users\\odevitt\\Downloads\\Bitstamp_BTCUSD_2021_minute.csv')

# %%
df1.sort_values(by=['date'],inplace=True, ascending=True)
df1
# Out:
#               unix                 date   symbol      open      high  \
# 564945  1609459260  2021-01-01 00:01:00  BTC/USD  29007.31  29086.90
# 564944  1609459320  2021-01-01 00:02:00  BTC/USD  29069.80  29073.02
# 564943  1609459380  2021-01-01 00:03:00  BTC/USD  29037.68  29069.39
# 564942  1609459440  2021-01-01 00:04:00  BTC/USD  29048.13  29057.73
# 564941  1609459500  2021-01-01 00:05:00  BTC/USD  29021.86  29023.38
# ...            ...                  ...      ...       ...       ...
# 4       1643355720  2022-01-28 07:42:00  BTC/USD  37004.15  37039.76
# 3       1643355780  2022-01-28 07:43:00  BTC/USD  37023.44  37023.44
# 2       1643355840  2022-01-28 07:44:00  BTC/USD  37029.44  37029.45
# 1       1643355900  2022-01-28 07:45:00  BTC/USD  37039.75  37042.26
# 0       1643355960  2022-01-28 07:46:00  BTC/USD  36997.36  37013.45
#
#              low     close  Volume BTC     Volume USD
# 564945  29007.31  29083.47   14.561951  423512.060397
# ...

# %%
df = df1.head(10000)
df.tail(10)
# Out:
#               unix                 date   symbol      open      high  \
# 554955  1610058660  2021-01-07 22:31:00  BTC/USD  39713.60  39750.00
# 554954  1610058720  2021-01-07 22:32:00  BTC/USD  39750.00  39777.44
# 554953  1610058780  2021-01-07 22:33:00  BTC/USD  39762.38  39799.84
# 554952  1610058840  2021-01-07 22:34:00  BTC/USD  39800.00  39900.00
# 554951  1610058900  2021-01-07 22:35:00  BTC/USD  39877.10  39909.20
# 554950  1610058960  2021-01-07 22:36:00  BTC/USD  39880.96  39920.82
# 554949  1610059020  2021-01-07 22:37:00  BTC/USD  39901.29  39995.51
# 554948  1610059080  2021-01-07 22:38:00  BTC/USD  39971.71  39982.54
# 554947  1610059140  2021-01-07 22:39:00  BTC/USD  39954.11  39967.56
# 554946  1610059200  2021-01-07 22:40:00  BTC/USD  39701.41  39873.85
#
#              low     close  Volume BTC     Volume USD
# 554955  39692.82  39750.00    6.790959  269940.624623
# 554954  39747.31  39762.38   17.256055  686141.833706
# ...

# %%
buy1btc = 29007.31
bank = 0

for i in df['open']:
    for i in df['open']:
        if (i) > (buy1btc + (buy1btc/20)):
            bank = bank +(i - buy1btc)
            buy1btc = i
            print('sell')
            break
        elif (i) < (buy1btc - (buy1btc/20)):
            buy1btc = i
            print ('buy')
            break
        else:
            buy1btc = buy1btc
# Out:
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# sell
# buy
# sell
# buy
# sell
# buy
# sell
# ...

# %%
buy1btc
# Out:
# 28785.98

# %%
for i,elem in enumerate(df['open'],1):
    for elem in df['open']:
        if (elem) > (buy1btc + (buy1btc/20)):
                bank = bank +(elem - buy1btc)
                buy1btc = elem
                print('sell')
                break
        elif (elem) < (buy1btc - (buy1btc/20)):
                buy1btc = elem
                print ('buy')
                break
        else:
            buy1btc = buy1btc
            print(\"iteration %d, elem %s\" %  "" (i, elem))"
                  
                  
                  print("iteration %d, elem %s" %  
         (i, elem))
# Out:
#   File "C:\Users\odevitt\AppData\Local\Temp/ipykernel_10948/1384238509.py", line 14
#     print(\"iteration %d, elem %s\" %  "" (i, elem))"
#                                                     ^
# SyntaxError: unexpected character after line continuation character
